# %% [markdown]
# # 5. Route B — Sz.-Nagy dilation and the price of non-complete-positivity

# %% [markdown]
# ## Konstruktion der dynamischen Karten $\mathcal{E}_n$ via HEOM
#
# Bevor wir die Transfer-Tensoren $T_m$ bestimmen können, benötigen wir die Kurzzeit-Dynamik des Systems. Das Ziel ist es, eine Familie von dynamischen Karten (Superoperatoren) $\mathcal{E}_n \equiv \mathcal{E}(n\Delta t)$ zu finden, die uns für jeden beliebigen Startzustand $\rho_S(0)$ die reduzierte Dichtematrix zu einem späteren Zeitpunkt liefert:
#
# $$\rho_S(n\Delta t) = \mathcal{E}_n \rho_S(0)$$
#
# Im nicht-Markovschen Fall ist das Bad kein passiver Zuschauer: Es merkt sich Wechselwirkungen und tauscht Energie sowie Korrelationen mit dem System aus. Die Standard-HEOM (Hierarchical Equations of Motion) löst dieses Problem, indem sie den Zustandsraum erweitert. Wir fassen die vektorisierte Systemdichtematrix $\text{vec}(\rho_S)$ und das dynamische Gedächtnis des Bades in einem einzigen großen Super-Vektor $\vec{\Sigma}(t)$ zusammen:
#
# $$\vec{\Sigma}(t) = \begin{pmatrix} \text{vec}(\rho_S(t)) \\ \text{vec}(\mathrm{ADO}_1(t)) \\ \vdots \\ \text{vec}(\mathrm{ADO}_{\mathcal{N}_{\mathrm{ADOs}}-1}(t)) \end{pmatrix} \in \mathbb{C}^{\mathcal{D}_{\mathrm{tot}}}$$
#
# * **$\text{vec}(\rho_S)$ (oberster Block):** Die vektorisierte Systemdichtematrix der Dimension $d^2$ (*zeroth-order ADO*).
# * **$\text{vec}(\mathrm{ADO}_k)$ (untere Blöcke):** Die vektorisierten Hilfsoperatoren (*Auxiliary Density Operators*), die jeweils ebenfalls $d \times d$-Matrizen darstellen und die quantenmechanischen Bad-Korrelationen speichern.
# * **Gesamtdimension:** Da $\mathcal{N}_{\mathrm{ADOs}}$ Matrizen der Dimension $d \times d$ untereinander gestapelt sind, beträgt die Gesamtlänge des Vektors $\mathcal{D}_{\mathrm{tot}} = \mathcal{N}_{\mathrm{ADOs}} \cdot d^2$.
#
# Auf diesem erweiterten Raum ist die Zeitevolution lokal in der Zeit (formal Markovsch) und gehorcht dem linearen Differentialgleichungssystem:
#
# $$\frac{\mathrm{d}}{\mathrm{d}t} \vec{\Sigma}(t) = \mathcal{L}_{\mathrm{HEOM}} \vec{\Sigma}(t)$$
#
# wobei der zeitunabhängige HEOM-Liouville-Superoperator $\mathcal{L}_{\mathrm{HEOM}}$ eine Matrix der Größe $\mathcal{D}_{\mathrm{tot}} \times \mathcal{D}_{\mathrm{tot}}$ darstellt. Die Zeitentwicklung über einen festen Zeitschritt $\Delta t$ lässt sich exakt über das Matrixexponential ausdrücken:
#
# $$P = \exp(\mathcal{L}_{\mathrm{HEOM}} \Delta t) \in \mathbb{C}^{\mathcal{D}_{\mathrm{tot}} \times \mathcal{D}_{\mathrm{tot}}} \implies \vec{\Sigma}(t+\Delta t) = P \ @ \ \vec{\Sigma}(t)$$
#
# Dieser Ein-Schritt-Propagator $P$ wird numerisch nur ein einziges Mal berechnet. Um aus der Gesamtdynamik von $P$ die universelle System-Abbildung $\mathcal{E}_n$ für beliebige Anfangszustände zu isolieren, nutzen wir die Linearität der Propagationsgleichung:
#
# **1. Basiszustände und Startmatrix $X_0$**
#
# Ein einzelner Vektor $\vec{\Sigma}(0)$ beschreibt nur eine konkrete Anfangsdichtematrix $\rho_S(0)$. Um die universelle Abbildung $\mathcal{E}_n$ zu bestimmen, definieren wir für jeden der $d^2$ orthonormalen Standardbasisvektoren $\vec{e}_j \in \mathbb{C}^{d^2}$ des Systemraums einen zugehörigen Gesamtzustand $\vec{\Sigma}^{(j)}(0)$, bei dem zu Beginn alle Bad-ADOs verschwinden:
#
# $$\vec{\Sigma}^{(j)}(0) = \begin{pmatrix} \vec{e}_j \\ \mathbf{0} \end{pmatrix} \in \mathbb{C}^{\mathcal{D}_{\mathrm{tot}}}$$
#
# Fassen wir alle $d^2$ Basisvektoren als Spalten in einer Matrix $X_0 \in \mathbb{C}^{\mathcal{D}_{\mathrm{tot}} \times d^2}$ zusammen, erhalten wir:
#
# $$X_0 =
# \left(\begin{array}{cccc}
# \mid & \mid & & \mid \\
# \vec{\Sigma}^{(1)}(0) & \vec{\Sigma}^{(2)}(0) & \cdots & \vec{\Sigma}^{(d^2)}(0) \\
# \mid & \mid & & \mid
# \end{array}\right)
# =
# \left(\begin{array}{cccc}
# \mid & \mid & & \mid \\
# \vec{e}_1 & \vec{e}_2 & \cdots & \vec{e}_{d^2} \\
# \mid & \mid & & \mid \\
# \hline
# \mathbf{0} & \mathbf{0} & \cdots & \mathbf{0} \\
# \vdots & \vdots & \ddots & \vdots \\
# \mathbf{0} & \mathbf{0} & \cdots & \mathbf{0}
# \end{array}\right)
# =
# \begin{pmatrix} \mathbb{I}_{d^2} \\ \mathbf{0} \end{pmatrix}$$
#
# **2. Lineare Propagation auf dem Gesamtraum**
#
# Nach $n$ Zeitschritten liefert die Multiplikation $X_n = P^n X_0$ die Entwicklung aller Basiszustände gleichzeitig, da $P^n$ spaltenweise auf jeden Vektor $\vec{\Sigma}^{(j)}(0)$ wirkt:
#
# $$X_n = P^n X_0 = P^n \begin{pmatrix} \mathbb{I}_{d^2} \\ \mathbf{0} \end{pmatrix} = [P^n \vec{\Sigma}^{(1)}(0) \;\; P^n \vec{\Sigma}^{(2)}(0) \;\; \dots] =  \left(\begin{array}{cccc} \mid & \mid & & \mid \\ \text{vec}\big(\rho_S^{(1)}(n\Delta t)\big) & \text{vec}\big(\rho_S^{(2)}(n\Delta t)\big) & \cdots & \text{vec}\big(\rho_S^{(d^2)}(n\Delta t)\big) \\ \mid & \mid & & \mid \\ \hline \text{vec}\big(\mathrm{ADO}_1^{(1)}(n\Delta t)\big) & \text{vec}\big(\mathrm{ADO}_1^{(2)}(n\Delta t)\big) & \cdots & \text{vec}\big(\mathrm{ADO}_1^{(d^2)}(n\Delta t)\big) \\ \vdots & \vdots & \ddots & \vdots \\ \text{vec}\big(\mathrm{ADO}_K^{(1)}(n\Delta t)\big) & \text{vec}\big(\mathrm{ADO}_K^{(2)}(n\Delta t)\big) & \cdots & \text{vec}\big(\mathrm{ADO}_K^{(d^2)}(n\Delta t)\big) \end{array}\right)$$
#
# Hierbei ist $\text{vec}\big(\rho_S^{(j)}(n\Delta t)\big)$ die resultierende vektorisierte Systemdichtematrix zur Zeit $t_n = n\Delta t$, wenn das System bei $t = 0$ im $j$-ten Basiszustand $\vec{e}_j$ gestartet ist.
#
# **3. Projektion auf den Systemblock**
#
# Da uns für die dynamische Karte $\mathcal{E}_n$ ausschließlich der physikalische Systemzustand interessiert, projizieren wir die während der Propagation aufgebauten ADO-Zeilen mit $Q = \begin{pmatrix} \mathbb{I}_{d^2} & \mathbf{0} \end{pmatrix}, Q^\dagger = \begin{pmatrix} \mathbb{I}_{d^2} \\ \mathbf{0} \end{pmatrix} \in \mathbb{C}^{d^2 \times \mathcal{D}_{\mathrm{tot}}}$ heraus:
#
# $$\mathcal{E}_n = Q \, X_n = Q \, P^n \begin{pmatrix} \mathbb{I}_{d^2} \\ \mathbf{0} \end{pmatrix} = Q \, P^n \, Q^T =
# \begin{pmatrix}
# \mid & \mid & & \mid \\
# \text{vec}\big(\rho_S^{(1)}(n\Delta t)\big) & \text{vec}\big(\rho_S^{(2)}(n\Delta t)\big) & \cdots & \text{vec}\big(\rho_S^{(d^2)}(n\Delta t)\big) \\
# \mid & \mid & & \mid
# \end{pmatrix} \in \mathbb{C}^{d^2 \times d^2}$$
#
# Jede Spalte $j$ von $\mathcal{E}_n$ ist somit exakt der vektorisierte Systemzustand, der aus dem Basis-Startzustand $\vec{e}_j$ hervorgeht.
#
# Die resultierende Sequenz $\{\mathcal{E}_0 = \mathbb{I}_{d^2}, \mathcal{E}_1, \mathcal{E}_2, \dots, \mathcal{E}_K\}$ bildet das Fundament, aus dem wir im nächsten Schritt die Transfer-Tensoren konstruieren.
#
# **4. Ein konkretes Beispiel zur Linearität:**
#
# Stellen wir uns ein simples Zwei-Niveau-System vor ($d = 2$). Der vektorisierte Liouville-Raum hat $d^2 = 4$ Dimensionen mit der Standardbasis $\vec{e}_1, \vec{e}_2, \vec{e}_3, \vec{e}_4$ (wobei $\vec{e}_1$ der reinen Population $|1\rangle\langle 1|$ und $\vec{e}_4$ der reinen Population $|2\rangle\langle 2|$ entspricht).
#
# Die Konstruktion der Abbildung $\mathcal{E}_n$ geschieht durch die Propagation dieser vier Basisvektoren. Die resultierenden Spaltenvektoren (die Basislösungen zum Zeitpunkt $t_n$) bezeichnen wir mit $\vec{c}_1, \vec{c}_2, \vec{c}_3, \vec{c}_4$. Die Superoperator-Matrix $\mathcal{E}_n$ setzt sich somit spaltenweise zusammen:
#
# $$\mathcal{E}_n = \begin{pmatrix} \mid & \mid & \mid & \mid \\ \vec{c}_1 & \vec{c}_2 & \vec{c}_3 & \vec{c}_4 \\ \mid & \mid & \mid & \mid \end{pmatrix}$$
#
# Betrachten wir nun einen allgemeinen, gemischten Anfangszustand ohne Kohärenzen, der zu 60% aus Zustand 1 und zu 40% aus Zustand 2 besteht:
#
# $$\rho_S(0) = \begin{pmatrix} 0.6 & 0 \\ 0 & 0.4 \end{pmatrix} \implies \vec{\rho}_S(0) = 0.6 \cdot \vec{e}_1 + 0.4 \cdot \vec{e}_4 = \begin{pmatrix} 0.6 \\ 0.0 \\ 0.0 \\ 0.4 \end{pmatrix}$$
#
# Die Zeitentwicklung dieses Zustands ergibt sich durch Multiplikation mit $\mathcal{E}_n$. Aufgrund der Linearität der Matrixmultiplikation lässt sich der Ausdruck distributiv zerlegen:
#
# $$\vec{\rho}_S(t_n) = \mathcal{E}_n \vec{\rho}_S(0) = \mathcal{E}_n (0.6 \vec{e}_1 + 0.4 \vec{e}_4) = 0.6 (\mathcal{E}_n \vec{e}_1) + 0.4 (\mathcal{E}_n \vec{e}_4)$$
#
# Da die Wirkung der Matrix auf die kanonischen Einheitsvektoren exakt die entsprechenden Spalten $\mathcal{E}_n \vec{e}_j = \vec{c}_j$ liefert, vereinfacht sich die Gesamtlösung zu einer Linearkombination:
#
# $$\vec{\rho}_S(t_n) = 0.6 \cdot \vec{c}_1 + 0.4 \cdot \vec{c}_4$$
#
# Die mathematische Linearität spiegelt das Superpositionsprinzip offener Quantensysteme wider:
#
# * Der Anteil der Wahrscheinlichkeitsdichte, der sich zu Beginn auf Niveau 1 befindet (60%), propagiert entlang der Lösung $\vec{c}_1$.
# * Der Anteil auf Niveau 2 (40%) propagiert unabhängig davon entlang der Lösung $\vec{c}_4$.
# * Die Gesamtdynamik zum Zeitpunkt $t_n$ ist die gewichtete Summe beider Teilentwicklungen.
#
# Da jede beliebige Dichtematrix als Linearkombination der Liouville-Basiselemente darstellbar ist, genügt die einmalige Berechnung der Spalten $\vec{c}_j$ zur Bestimmung der vollständigen, universellen Dynamik $\mathcal{E}_n$. Eine dynamische Karte $\mathcal{E}_n$ ist also kein Gleichungslöser, sondern das kompakt verpackte Resultat einer bereits durchgeführten Lösung.

# %% [markdown]
# ## Der Transfertensors
#
# Gegeben sei ein Anfangszustand $\rho_0$. Die Zeitentwicklung zu einem beliebigen Schritt $n$ wird durch eine Familie von dynamischen Karten (Superoperatoren) $\mathcal{E}_n$ beschrieben (das ist bei uns `maps`), sodass:$$\rho_n = \mathcal{E}_n \rho_0$$
#
# Da wir uns im nicht-Markovschen Regime befinden, hängt der aktuelle Zustand von der gesamten Vergangenheit ab: $$\rho_n = \sum_{m=1}^n T_m \rho_{n-m}$$Hier ist $T_m$ der Transfer-Tensor. Wir können sagen dass $\rho_n$ eine Linearkombination von alten Zuständen ist, da sowohl die unitäre Entwicklung $\rho_S(t) = \text{Tr}_B [ U(t) (\rho_S(0) \otimes \rho_B(0)) U^\dagger(t) ]$ als auch die Spur linear sind. Mit den obigen beidden Gleichungen ergibt sich der Transfertensor als: $$\mathcal{E}_n \rho_0 = \sum_{m=1}^n T_m \mathcal{E}_{n-m} \rho_0$$Da diese Gleichung für jeden beliebigen Anfangszustand $\rho_0$ gelten muss, können wir $\rho_0$ weglassen und erhalten eine Operatorgleichung:$$\mathcal{E}_n = \sum_{m=1}^n T_m \mathcal{E}_{n-m}$$Um nun den Tensor $T_n$ für den aktuellen Schritt zu isolieren, spalten wir den letzten Term (für $m=n$) von der Summe ab. Wir wissen, dass $\mathcal{E}_0 = \mathbb{I}$ (der nullte Schritt verändert das System nicht). Also ist der Term für $m=n$ einfach $T_n \mathcal{E}_0 = T_n$. Umgestellt nach $T_n$ ergibt das:$$T_n = \mathcal{E}_n - \sum_{m=1}^{n-1} T_m \mathcal{E}_{n-m}$$Hiermit wird aus der exakten Gesamtdynamik iterativ der reine Kurzzeit- und Gedächtnisanteil herausgefiltert. In der Praxis schneidet man diese Reihe nach $K$ Schritten ab, da das Bad irgendwann "vergisst" ($T_{m > K} \approx 0$).
#
# Da $\mathcal{E}_n \equiv \mathcal{E}(n\Delta t)$ und somit $\mathcal{E}_0=1$ (Propagieren um 0 Zeitschritte macht nichts) folgt $\mathcal{E}_1 = \sum_{m=1}^1 T_m \mathcal{E}_{1-m} = T_1 \mathcal{E}_0 = T_1$. Daraus folgt wiederum:
# $$T_2 = \mathcal{E}_2 - \sum_{m=1}^{2-1} T_m \mathcal{E}_{2-m} = \mathcal{E}_2 - T_1 \mathcal{E}_{1} = \mathcal{E}_2 - \mathcal{E}_{1} \mathcal{E}_{1}$$
# $$T_3 = \mathcal{E}_3 - \sum_{m=1}^{2} T_m \mathcal{E}_{3-m} = \mathcal{E}_3 - \left( T_1 \mathcal{E}_2 + T_2 \mathcal{E}_1 \right) = \mathcal{E}_3 - \mathcal{E}_1 \mathcal{E}_2 - \left( \mathcal{E}_2 - \mathcal{E}_1 \mathcal{E}_1 \right) \mathcal{E}_1 = \mathcal{E}_3 - \mathcal{E}_1 \mathcal{E}_2 - \mathcal{E}_2 \mathcal{E}_1 + \mathcal{E}_1 \mathcal{E}_1 \mathcal{E}_1$$

# %% [markdown]
# ## Der Companionpropagator
# Die Transfer-Tensor-Gleichung, die wir gerade hergeleitet haben, benötigt also die Historie:$$\rho_n \approx T_1 \rho_{n-1} + T_2 \rho_{n-2} + \dots + T_K \rho_{n-K}$$
#
# Anstatt nur die aktuelle Dichtematrix $\rho$ zu betrachten, definieren wir einen großen Blockvektor $X$, der ein "gleitendes Fenster" (sliding window) der letzten $K$ Zustände enthält. Wenn wir uns im Schritt $n-1$ befinden, sieht unser Input-Register so aus:$$X_{n-1} = \begin{pmatrix} \rho_{n-1} \\ \rho_{n-2} \\ \rho_{n-3} \\ \vdots \\ \rho_{n-K} \end{pmatrix}$$Unser Ziel ist es, einen einzigen Operator $E$ zu finden, der diesen Vektor einen Zeitschritt in die Zukunft propagiert: $X_n = E X_{n-1}$.
#
# Der Operator $E$ muss zwei Aufgaben gleichzeitig erfüllen:
# - Den neuen Zustand $\rho_n$ berechnen und in die oberste Position schreiben.
# - Alle alten Zustände um eine Position nach unten verschieben (wobei der älteste Zustand $\rho_{n-K}$ aus dem Register "herausfällt").
#
# Dies geschieht durch eine sogenannte Block-Begleitmatrix (Companion Matrix). Sie hat folgende Struktur:$$E = \begin{pmatrix}  T_1 & T_2 & T_3 & \dots & T_K \\  \mathbb{I} & 0 & 0 & \dots & 0 \\  0 & \mathbb{I} & 0 & \dots & 0 \\  \vdots & \vdots & \ddots & \ddots & \vdots \\  0 & 0 & \dots & \mathbb{I} & 0  \end{pmatrix}$$
#
# Wenn du nun das Matrix-Vektor-Produkt $E X_{n-1}$ im Kopf ausführst, siehst du, was passiert:
# - Die erste Zeile multipliziert sich mit dem Vektor zu: $T_1 \rho_{n-1} + T_2 \rho_{n-2} + \dots + T_K \rho_{n-K}$. Das ist genau unser gesuchtes $\rho_n$.
# - Die zweite Zeile besteht nur aus einer Identitätsmatrix $\mathbb{I}$ an der ersten Position. Sie greift sich also einfach $\rho_{n-1}$ und schiebt es in die zweite Zeile des neuen Vektors.
# - Die dritte Zeile greift sich $\rho_{n-2}$ und so weiter.
#
# **Warum die Propagation mit den Companiontensor nur eine Approximation ist:**
#
# Die zugrunde liegende Formel: $\rho_n = \sum_{m=1}^n T_m \rho_{n-m} = \underbrace{\sum_{m=1}^K T_m \rho_{n-m}}_{\text{dein Begleitoperator } E} + \underbrace{\sum_{m=K+1}^n T_m \rho_{n-m}}_{\text{der abgeschnittene Gedächtnis-Rest } R_n}$
#
# | Schritt | Approximation ($X_n = E X_{n-1}$) | Exakter Zustand ($\rho_n = \sum_{m=1}^n T_m \rho_{n-m}$) | Fehler ($R_n$) |
# | :---: | :--- | :--- | :---: |
# | **$n = 1$** | $X_1 = \begin{pmatrix} T_1 & T_2 & T_3 \\ \mathbb{I} & 0 & 0 \\ 0 & \mathbb{I} & 0 \end{pmatrix} \begin{pmatrix} \rho_0 \\ 0 \\ 0 \end{pmatrix} = \begin{pmatrix} T_1 \rho_0 \\ \rho_0 \\ 0 \end{pmatrix} = \begin{pmatrix} \rho_1 \\ \rho_0 \\ 0 \end{pmatrix}$ | $\rho_1 = T_1 \rho_0$ | $0$ |
# | **$n = 2$** | $X_2 = \begin{pmatrix} T_1 & T_2 & T_3 \\ \mathbb{I} & 0 & 0 \\ 0 & \mathbb{I} & 0 \end{pmatrix} \begin{pmatrix} \rho_1 \\ \rho_0 \\ 0 \end{pmatrix} = \begin{pmatrix} T_1 \rho_1 + T_2 \rho_0 \\ \rho_1 \\ \rho_0 \end{pmatrix} = \begin{pmatrix} \rho_2 \\ \rho_1 \\ \rho_0 \end{pmatrix}$ | $\rho_2 = T_1 \rho_1 + T_2 \rho_0$ | $0$ |
# | **$n = 3$** | $X_3 = \begin{pmatrix} T_1 & T_2 & T_3 \\ \mathbb{I} & 0 & 0 \\ 0 & \mathbb{I} & 0 \end{pmatrix} \begin{pmatrix} \rho_2 \\ \rho_1 \\ \rho_0 \end{pmatrix} = \begin{pmatrix} T_1 \rho_2 + T_2 \rho_1 + T_3 \rho_0 \\ \rho_2 \\ \rho_1 \end{pmatrix} = \begin{pmatrix} \rho_3 \\ \rho_2 \\ \rho_1 \end{pmatrix}$ | $\rho_3 = T_1 \rho_2 + T_2 \rho_1 + T_3 \rho_0$ | $0$ |
# | **$n = 4$** | $X_4 = \begin{pmatrix} T_1 & T_2 & T_3 \\ \mathbb{I} & 0 & 0 \\ 0 & \mathbb{I} & 0 \end{pmatrix} \begin{pmatrix} \rho_3 \\ \rho_2 \\ \rho_1 \end{pmatrix} = \begin{pmatrix} T_1 \rho_3 + T_2 \rho_2 + T_3 \rho_1 \\ \rho_3 \\ \rho_2 \end{pmatrix} = \begin{pmatrix} \rho_4 \\ \rho_3 \\ \rho_2 \end{pmatrix}$ | $\rho_4 = T_1 \rho_3 + T_2 \rho_2 + T_3 \rho_1 + \mathbf{T_4 \rho_0}$ | $\mathbf{T_4 \rho_0}$ |
# | **$n = 5$** | $X_5 = \begin{pmatrix} T_1 & T_2 & T_3 \\ \mathbb{I} & 0 & 0 \\ 0 & \mathbb{I} & 0 \end{pmatrix} \begin{pmatrix} \rho_4 \\ \rho_3 \\ \rho_2 \end{pmatrix} = \begin{pmatrix} T_1 \rho_4 + T_2 \rho_3 + T_3 \rho_2 \\ \rho_4 \\ \rho_3 \end{pmatrix} = \begin{pmatrix} \rho_5 \\ \rho_4 \\ \rho_3 \end{pmatrix}$ | $\rho_5 = T_1 \rho_4 + T_2 \rho_3 + T_3 \rho_2 + \mathbf{T_4 \rho_1 + T_5 \rho_0}$ | $\mathbf{T_4 \rho_1 + T_5 \rho_0}$ |
# | **$n = 6$** | $X_6 = \begin{pmatrix} T_1 & T_2 & T_3 \\ \mathbb{I} & 0 & 0 \\ 0 & \mathbb{I} & 0 \end{pmatrix} \begin{pmatrix} \rho_5 \\ \rho_4 \\ \rho_3 \end{pmatrix} = \begin{pmatrix} T_1 \rho_5 + T_2 \rho_4 + T_3 \rho_3 \\ \rho_5 \\ \rho_4 \end{pmatrix} = \begin{pmatrix} \rho_6 \\ \rho_5 \\ \rho_4 \end{pmatrix}$ | $\rho_6 = T_1 \rho_5 + T_2 \rho_4 + T_3 \rho_3 + \mathbf{T_4 \rho_2 + T_5 \rho_1 + T_6 \rho_0}$ | $\mathbf{T_4 \rho_2 + T_5 \rho_1 + T_6 \rho_0}$ |
# | $\vdots$ | $\vdots$ | $\vdots$ | $\vdots$ |

# %% [markdown]
# ## Warum Sz.-Nagy das Problem löst
# Da $E$ weder CPTP ist noch die Norm erhält, existiert schlichtweg keine Isometrie $V$, die $E$ deterministisch in einen größeren unitären Raum einbettet. Somit funktioniert die Stinespring dilation nicht. Daher gehen wir zur Sz.-Nagy Dilation über die aus jeder beliebige Matrix $A$ eine unitäre Matrix macht, solange diese eine Kontraktion ist (also $\Vert{}A\Vert{}_2 = \max_{x \neq 0} \frac{\Vert{}Ax\Vert{}}{\Vert{}x\Vert{}} \le 1$).Das Vorgehen sieht so aus:
# - Schritt 1: Normierung zur Kontraktion:
# Da $\Vert{}E\Vert{}_2 \approx \sqrt{2}$ größer als 1 ist, definieren wir eine skalierte Version welche $\Vert{}A\Vert{}_2 \le 1$ garantiert sodass $A$ eine Kontraktion ist :$$A = \frac{E}{s} \quad \text{mit} \quad s = \Vert{}E\Vert{}_2$$
#
# - Schritt 2: Einbettung in eine unitäre Matrix:
# Weil $A$ eine Kontraktion ist, können wir die Hermiteschen, positiv semidefiniten Matrizen $B = \sqrt{\mathbb{1} - AA^\dagger}$ und $C = \sqrt{\mathbb{1} - A^\dagger A}$ berechnen (Lemma 10). Damit lässt sich $A$ als oberer linker Block in eine größere unitäre Matrix $U$ einbauen:$$U = \begin{pmatrix} E/s & B \\ C & -(E/s)^\dagger \end{pmatrix}$$
#
# ## Post-Selection and its probability
# ### One step
#
# Wir führen den Zustand ("Super-Vektor") $\vert{}X\rangle$ ein, in den wir die gesamte Dichtematrix des Systems sowie das Gedächtnis an die jüngsten $K$ Zeitschritte codiert haben. Da vektorisierte Dichtematrizen im Allgemeinen nicht die $L^2$-Norm 1 besitzen, muss dieser Vektor vor der Übergabe an den Quantencomputer klassisch normiert werden. Wir zerlegen $X$ daher in seine skalare Länge und seine normierte Richtung: $X = \Vert X \Vert \cdot \frac{X}{\Vert X \Vert} = \Vert X \Vert \cdot Y$.
#
# Da $E$ eine physikalische Dynamik beschreibt (z. B. den Zerfall von Populationen oder den Verlust von Kohärenzen), ändert $E$ die Länge von $X$ stetig, sodass bereits nach einem Schritt $\Vert X \Vert \neq 1$ gilt. Wenn wir das unitäre Gatter $U$ auf den Zustand anwenden, zieht man die klassische Norm dank der Linearität vor den quantenmechanischen Ausdruck, da der Quantencomputer ausschließlich mit dem normierten Zustand $|Y\rangle$ arbeitet:
#
# $$\Vert X \Vert \cdot U \big(|0\rangle_E \otimes |Y\rangle\big) = \Vert X \Vert \begin{pmatrix} (E/s)\,Y \\ C\,Y \end{pmatrix} = \Vert X \Vert \cdot \left[ \vert{}0\rangle_E \otimes \left(\frac{E}{s} Y\right) + \vert{}1\rangle_E \otimes (CY) \right]$$
#
# Damit wir den gewünschten Propagations-Schritt $(E/s)Y$ (den oberen Block) erhalten, messen wir das Ancilla-Qubit und fordern zwingend das Ergebnis $\vert{}0\rangle$. Wenn das Ancilla-Qubit als $\vert{}1\rangle$ gemessen wird (was dem unteren Block $CY$ entspricht), ist der Durchlauf fehlgeschlagen und wird verworfen. Nach der Bornschen Regel tritt das Ergebnis $\vert{}0\rangle$ auf dem normierten Quantenzustand $|Y\rangle$ mit folgender Wahrscheinlichkeit auf:
#
# $$p = \left\Vert \frac{E}{s} Y \right\Vert^2 = \frac{\Vert EY \Vert^2}{s^2} = \frac{\Vert EX \Vert^2}{s^2 \Vert X \Vert^2} \tag{5.2} \quad \implies \quad \Vert EY \Vert = s \cdot \sqrt{p}$$
#
# Bedingt auf dieses Messergebnis zwingt der quantenmechanische Kollaps das System-Register unwiderruflich in den zugehörigen Zweig $(E/s)Y$. Da physikalische Quantenzustände nach einer Messung normiert sein müssen, dividiert die Natur den Vektor automatisch durch seine eigene Länge:
#
# $$Y_{\text{nach Kollaps}} = \frac{(E/s)Y}{\Vert (E/s)Y \Vert} = \frac{\frac{1}{s} EY}{\frac{1}{s} \Vert EY \Vert} = \frac{EY}{\Vert EY \Vert} = \frac{EX}{\Vert EX \Vert}$$
#
# Da der Quantencomputer durch den Messkollaps stets einen Zustand mit $L^2$-Norm 1 ausgibt, der physikalische Vektor $EX$ seine Länge unter der dissipativen Zeitentwicklung jedoch kontinuierlich ändert, rekonstruieren wir den unnormierten Vektor klassisch:
#
# $$EX = \Vert X \Vert \cdot (EY) = \Vert X \Vert \cdot \Big( \Vert EY \Vert \cdot Y_{\text{nach Kollaps}} \Big) = \Big( \Vert X \Vert \cdot s \cdot \sqrt{p} \Big) \cdot Y_{\text{nach Kollaps}}$$
#
# Der Skalierungsfaktor $\Vert X \Vert \cdot s \cdot \sqrt{p}$ wird somit einfach auf dem klassischen Computer mitgeführt und im Post-Processing auf den Hardware-Zustand angewendet.
#
#
# ### Many steps
# Wenden wir $\bra{0}_E$ von links auf Gleichung (5.1) an und dividieren durch $||X||$, bekommen wir $EY = s \cdot \langle 0|_E U \Big(|0\rangle_E \otimes |Y\rangle \Big)$. Mit der Iteration $Y_n := EY_{n-1}$ bekommen wir:
# $$\begin{aligned} Y_n &= E Y_{n-1} = s \cdot \langle 0 \vert_E U \big( \vert{}0\rangle_E \otimes Y_{n-1} \big) = s \cdot \langle 0 \vert_E U \bigg( \vert{}0\rangle_E \otimes \Big[ s \cdot \langle 0 \vert_E U \big( \vert{}0\rangle_E \otimes Y_{n-2} \big) \Big] \bigg) \\ &= s \cdot \langle 0 \vert_E U \Bigg( \vert{}0\rangle_E \otimes \bigg[ s \cdot \langle 0 \vert_E U \Big( \vert{}0\rangle_E \otimes \big[ s \cdot \langle 0 \vert_E U ( \vert{}0\rangle_E \otimes Y_{n-3} ) \big] \Big) \bigg] \Bigg) \\ &\;\;\dots = s^n \cdot \underbrace{\langle 0 \vert_E U \Bigg( \vert{}0\rangle_E \otimes \dots \Big[ \langle 0 \vert_E U \big( \vert{}0\rangle_E \otimes Y_0 \big) \Big] \dots \Bigg) }_{n\text{-fache Schachtelung}} = E^n Y_0 \end{aligned}$$
#
#
# **Das Beispiel für $n=3$:**
# Lass uns das zur Intuition von innen nach außen auflösen. Wir nutzen dabei aus, dass $U(\vert{}0\rangle_E \otimes Y) = (E/s)Y \vert{}0\rangle_E + C Y \vert{}1\rangle_E$ ergibt:
# $$\begin{aligned} Y_3 &= s \cdot \langle 0 \vert_E U \Bigg( \vert{}0\rangle_E \otimes \bigg[ s \cdot \langle 0 \vert_E U \Big( \vert{}0\rangle_E \otimes \big[ s \cdot \langle 0 \vert_E U ( \vert{}0\rangle_E \otimes Y_0 ) \big] \Big) \bigg] \Bigg) = s \cdot \langle 0 \vert_E U \Bigg( \vert{}0\rangle_E \otimes \bigg[ s \cdot \langle 0 \vert_E U \Big( \vert{}0\rangle_E \otimes \underbrace{\big[ s \cdot \langle 0 \vert_E \big( (E/s) Y_0 \vert{}0\rangle_E + C Y_0 \vert{}1\rangle_E \big) \big]}_{= s \cdot (E/s) Y_0 \;=\; E Y_0 \;=\; Y_1} \Big) \bigg] \Bigg) \\ &= s \cdot \langle 0 \vert_E U \Bigg( \vert{}0\rangle_E \otimes \bigg[ s \cdot \langle 0 \vert_E U \big( \vert{}0\rangle_E \otimes Y_1 \big) \bigg] \Bigg) = s \cdot \langle 0 \vert_E U \Bigg( \vert{}0\rangle_E \otimes \underbrace{\bigg[ s \cdot \langle 0 \vert_E \big( (E/s) Y_1 \vert{}0\rangle_E + C Y_1 \vert{}1\rangle_E \big) \bigg]}_{= s \cdot (E/s) Y_1 \;=\; E Y_1 \;=\; Y_2} \Bigg) \\ &= s \cdot \langle 0 \vert_E U \big( \vert{}0\rangle_E \otimes Y_2 \big) = s \cdot \langle 0 \vert_E \big( (E/s) Y_2 \vert{}0\rangle_E + C Y_2 \vert{}1\rangle_E \big) = s \cdot (E/s) Y_2 = E Y_2 = Y_3 \end{aligned}$$
#
#
# > Proposition 13. Sei $X_{t+1} := EX_t$ die Folge unserer unnormierten, theoretischen Vektoren und somit $X_n = E^nX_0$. Wenn der Quantenschaltkreis die Sz.-Nagy-Dilatation $n$-mal hintereinander anwendet (jedes Mal mit einem neuen Ancilla-Qubit) und wir bei jedem dieser Qubits fordern, dass es als $\vert{}0\rangle$ gemessen wird (Post-Selection), dann ist die Gesamtwahrscheinlichkeit dafür:$$p_{\rm total} = \prod_{t=0}^{n-1}p_t = \frac{\Vert{}E^{n}X_0\Vert{}^{2}}{s^{2n}\Vert{}X_0\Vert{}^{2}}. \tag{5.3}$$
#
# Beweis. Mit $Y_t := X_t / \Vert X_t \Vert$, Gleichung (5.2) und $X_{t+1} = EX_t$ folgt für die Wahrscheinlichkeit für einen Erfolg in einem einzelnen Schritt:
# $$p_t = \frac{\Vert{}EY_t\Vert{}^2}{s^2} = \frac{\Vert{}EX_t\Vert{}^2}{s^2\Vert{}X_t\Vert{}^2} = \frac{\Vert{}X_{t+1}\Vert{}^2}{s^2\Vert{}X_t\Vert{}^2}.$$
# Wenn wir nun auf mehrere Schritte verallgemeinern und diese Wahrscheinlichkeiten miteinander multiplizieren, entsteht ein Teleskopprodukt:
# $$p_{\text{total}} = \prod_{t=0}^{n-1}p_t = \frac{1}{s^{2n}}\prod_{t=0}^{n-1}\frac{\Vert{}X_{t+1}\Vert{}^2}{\Vert{}X_t\Vert{}^2} = \frac{1}{s^{2n}} \cdot \left( \frac{\color{red}{\cancel{\Vert{}X_1\Vert{}^2}}}{\Vert{}X_0\Vert{}^2} \cdot \frac{\color{lightblue}{\cancel{\Vert{}X_2\Vert{}^2}}}{\color{red}{\cancel{\Vert{}X_1\Vert{}^2}}} \cdot \frac{\color{green}{\cancel{\Vert{}X_3\Vert{}^2}}}{\color{lightblue}{\cancel{\Vert{}X_2\Vert{}^2}}} \cdot \dots \cdot \frac{\color{orange}{\cancel{\Vert{}X_{n-1}\Vert{}^2}}}{\color{purple}{\cancel{\Vert{}X_{n-2}\Vert{}^2}}} \cdot \frac{\Vert{}X_n\Vert{}^2}{\color{orange}{\cancel{\Vert{}X_{n-1}\Vert{}^2}}} \right) = \frac{\Vert{}X_n\Vert{}^2}{s^{2n} \Vert{}X_0\Vert{}^2} = \frac{\Vert{}E^nX_0\Vert{}^2}{s^{2n} \Vert{}X_0\Vert{}^2} \qquad \blacksquare$$
#
# Ob wir die Ancilla-Qubits sofort nach ihrem jeweiligen Schritt messen oder alle gemeinsam ganz am Ende, spielt physikalisch überhaupt keine Rolle: Sobald der Zeitschritt $t$ vorbei ist, berührt kein einziges Gatter dieses spezifische Ancilla-Qubit $t$ jemals wieder. Daher vertauscht (kommutiert) diese Messung mit allem, was danach im Schaltkreis passiert, und die statistischen Resultate bleiben exakt gleich. Das ist das Prinzip der aufgeschobenen Messung (Deferred-Measurement Principle). Genau dieses Prinzip ermöglicht es, die Simulation als einen einzigen, durchgehenden Schaltkreis zu bauen, anstatt den Schaltkreis $n$-mal bedingt neu starten zu müssen.
#
# Formel (5.3) offenbart die eigentliche Hürde der Route B. Für unseren ursprünglichen Begleitoperator (Companion Operator) gilt $\Vert{}E\Vert{}_2 = \sqrt{2}$, während sein Spektralradius $\rho(E) = 1$ ist. Für $n=76$ Zeitschritte ergibt das $s^{2n} = (\sqrt{2})^{2\cdot 76} = 2^{76}$ und somit:
#
# $$p_{\rm total} = \frac{\Vert{}E^{n}X_0\Vert{}^{2}}{s^{2n}\Vert{}X_0\Vert{}^{2}} =\frac{1}{2^{76}}\cdot\frac{\Vert{}X_n\Vert{}^2}{\Vert{}X_0\Vert{}^2} \simeq \frac{\mathcal O(1)}{2^{76}} \approx 6.7 \times 10^{-24}.$$
#
# Man bräuchte also grob $10^{23}$ Durchläufe (Shots) für auch nur ein einziges verwertbares Messergebnis.

# %% [markdown]
# ### Die Umsetzung auf dem Quantencomputer:
#
# ```
# System-Qubits : ──────[ U ]──────[ U ]──────[ U ]────── ... ───> Y_n
#                        │          │          │
# Ancilla 1     :  |0> ──[ U ]──(M) │          │
# Ancilla 2     :  |0> ─────────────[ U ]──(M) │
# Ancilla 3     :  |0> ────────────────────────[ U ]──(M)
# ```
#
# Der Quantencomputer normiert Zustände nach Messungen jedoch automatisch, wodurch man die ursprüngliche Länge verlieren würde. Daher muss man den finalen normiert Zustand $Y_n \equiv E^nX_0 / ||E^nX_0||$ den man aus den Zuständen der Systemqubits im Quantencomputer durch Quantentomographie bekommt noch mit seiner Länge skalieren. Aus dem Beweis von Formel $5.3$ kann man diese Länge einfach ablesen:
#
# $$p_{\text{total}} = \frac{\Vert{}E^nX_0\Vert{}^2}{s^{2n} \Vert{}X_0\Vert{}^2} \quad \rightarrow \quad \Vert{}E^nX_0\Vert{} = s^{n} \Vert{}X_0\Vert{}\sqrt{p_{\text{total}}}$$
#
# Somit berechnet sich der finale Zustand $X_n$ aus dem normierten Outputzustand $Y_n$ des Quantencoputers wie folgt:
# $$X_n = E^nX_0 = ||E^nX_0|| \cdot \frac{E^nX_0}{||E^nX_0||} = s^{n} \Vert{}X_0\Vert{}\sqrt{p_{\text{total}}} \cdot Y_n = \underbrace{ \Big( ||X_0|| \cdot s^n \cdot \sqrt{p_{\rm total}} \Big) }_{\mathbf{=\, \lambda_n}} \cdot \; Y_n$$
# Das $\lambda_n$ ist exakt das Produkt aus dem anfänglichen Startfaktor $\lambda_0$, der $n$-fachen Bestrafung durch die unitäre Matrix-Schrumpfung ($s^n$) und der am Ende gemessenen Wahrscheinlichkeit ($\sqrt{p_{\rm total}}$).
#
#
# | Variable | Bedeutung | Woher kommt der Wert? | Wann / Wo im Ablauf? |
# | :--- | :--- | :--- | :--- |
# | $\mathbf{\Vert X_0 \Vert}$ | Initiale Länge des Super-Vektors | $\Vert X_0 \Vert$ | **Vor dem Quanten-Run** (rein klassisch aus dem Startzustand $X_0$). |
# | $\mathbf{s}$ | Dilatations-Skalierungsfaktor | $s = \Vert H_m \Vert_2 \cdot (1 + 10^{-12})$ | **Vor dem Quanten-Run** (rein klassisch aus der Arnoldi-Matrix $H_m$). |
# | $\mathbf{p_{\rm total}}$ | Kumulierte Erfolgswahrscheinlichkeit | $p_{\rm total} \approx \frac{N_{\text{success}}}{N_{\text{shots}}}$ über die Häufigkeit des Bitstrings `"00...0"` der Ancilla | **Nach dem Durchlauf** (aus dem klassischen Zählregister `cr` der Ancilla-Messungen). |
# | $\mathbf{Y_n}$ | Normierter Endzustand der System-Qubits | Quantenzustand der $m$-System-Qubits bedingt auf die erfolgreichen Shots (Messung / Tomographie am Ende) | **Ganz am Ende des Circuits** (am finalen Zeitschritt $t=n$). |

# %% [markdown]
# ## Die fundamentale Diskrepanz der Operatornorm
#
# Um die Ursache für die winzige Erfolgswahrscheinlichkeit zu verstehen, zerlegen wir Gleichung (5.3) gedanklich in zwei Faktoren:
#
# $$p_{\rm total} = \underbrace{\frac{1}{s^{2n}}}_{\text{Teil 1 (Gatter-Strafe)}} \cdot \underbrace{\frac{\Vert E^n X_0 \Vert^2}{\Vert X_0 \Vert^2}}_{\text{Teil 2 (Physikalischer Zerfall)}}$$
#
# Diese Gesamtwahrscheinlichkeit wird durch zwei völlig unterschiedliche Mechanismen bestimmt.
# - **Teil 1** ist ein reines Hardware-Artefakt: Damit das Quantengatter unitär ist, zwingt uns die Mathematik zu einem Skalierungsfaktor $s$, der dem globalen Worst-Case der Operatornorm ($\Vert E \Vert_2$) entspricht.
# - **Teil 2** hingegen beschreibt das reale Verhalten der echten physikalischen Trajektorie.
#
# Wir werden nun zeigen, dass Teil 2 völlig harmlos ist und die Katastrophe ausschließlich von Teil 1 ausgeht. Da das Quantengatter jedoch stur den Worst-Case verlangt, wird uns diese Diskrepanz im nächsten Kapitel zwingen, die Matrix $E$ durch die Arnoldi-Kompression an die reale Physik anzupassen.
#
# **Die Analyse von Teil 1: Die untere Schranke der Operatornorm**
#
# Um die minimale Größe von $s = \Vert E \Vert_2$ zu bestimmen, nutzen wir die Eigenschaft der Operatornorm als Supremum über alle möglichen Testzustände.
#
# > **Proposition 14a.** Die Operatornorm des Companion-Propagators $E$ ist streng nach unten beschränkt durch:
# > $$ \Vert E \Vert_2 \equiv \sqrt{\sup_{Y\neq 0} \frac{\Vert{}EY\Vert{}}{\Vert{}Y\Vert{}}} \ge \sqrt{1 + \Vert T_1 \Vert_2^2} \tag{6.1b} $$
#
# Beweis. Die $L^2$-Matrixnorm ist definiert als: $ \Vert E \Vert_2^2 = \sup_{Y\neq 0} \frac{\Vert{}EY\Vert{}}{\Vert{}Y\Vert{}} = \max_{\Vert Y \Vert = 1} \Vert EY \Vert^2 $, wobei wir ausgenutzt haben, dass $\Vert Y \Vert = 1$, da $E$ im Quantencircuit nur auf normierte Zustände wirkt. Da das absolute Maximum über alle Vektoren zwingend größer oder gleich dem Wert für *jeden speziellen* Testvektor der Länge 1 sein muss, wählen wir den Testzustand $X_{\text{test}} = (\rho, \mathbf{0}, \dots, \mathbf{0})^{\mathsf T}$ mit $\Vert \rho \Vert = 1$ (womit $\Vert X_{\text{test}} \Vert^2 = \Vert \rho \Vert^2 + \sum_{i=2}^K 0 = 1$ erfüllt ist). Wir werten die Wirkung von $E$ auf diesen Testvektor Schritt für Schritt aus:
#
# $$\begin{aligned}
# \Vert E \Vert_2^2 &\ge \Vert E X_{\text{test}} \Vert^2 = \left\Vert \begin{pmatrix} T_1 & T_2 & \dots & T_K \\ \mathbb{1} & \mathbf{0} & \dots & \mathbf{0} \\ \mathbf{0} & \mathbb{1} & \dots & \mathbf{0} \\ \vdots & \ddots & \ddots & \vdots \\ \mathbf{0} & \dots & \mathbb{1} & \mathbf{0} \end{pmatrix} \begin{pmatrix} \rho \\ \mathbf{0} \\ \mathbf{0} \\ \vdots \\ \mathbf{0} \end{pmatrix} \right\Vert^2 = \left\Vert \begin{pmatrix} T_1 \rho \\ \rho \\ \mathbf{0} \\ \vdots \\ \mathbf{0} \end{pmatrix} \right\Vert^2 = \Vert T_1 \rho \Vert^2 + \Vert \rho \Vert^2 + \sum_{i=3}^K \Vert \mathbf{0} \Vert^2 = \Vert T_1 \rho \Vert^2 + 1
# \end{aligned}$$
#
# Da diese Ungleichung für *jede* beliebige Dichtematrix $\rho$ mit $\Vert \rho \Vert = 1$ gilt, maximieren wir die rechte Seite über alle normierten $\rho$:
#
# $$\begin{aligned}
# \Vert E \Vert_2^2 &\ge \max_{\Vert \rho \Vert = 1} \Big( \Vert T_1 \rho \Vert^2 + 1 \Big) = \underbrace{ \max_{\Vert \rho \Vert = 1} \Vert T_1 \rho \Vert^2 }_{=\, \Vert T_1 \Vert_2^2} \;+\; 1 = \Vert T_1 \Vert_2^2 + 1 \quad \implies \quad \Vert E \Vert_2 \ge \sqrt{1 + \Vert T_1 \Vert_2^2}
# \end{aligned}$$
#
# Da für kurze Zeitschritte $T_1 = \mathcal{E}(\Delta t) \approx \mathbb{1}$ gilt und somit $\Vert T_1 \Vert_2 \approx 1$ ist, folgt zwingend $\Vert E \Vert_2 \ge \sqrt{1 + 1^2} = \sqrt{2} \approx 1.4142$. $\;\blacksquare$
#
# Dieser Wert entscheidet über das Schicksal von Teil 1: Der Nenner explodiert zu $s^{2n} = (\sqrt{2})^{2\cdot 76} = 2^{76}$, wodurch der erste Faktor auf winzige $1/2^{76} \approx 1.3 \times 10^{-23}$ einbricht. Aber betrachten wir den Zustand $X$, der dieses Maximum überhaupt erst auslöst: Er besitzt nur einen einzigen besetzten Block ($\rho_1 \neq 0$), während alle anderen Blöcke strikt null sind ($\rho_2 = \dots = \rho_K = 0$). Physikalisch entspräche das einem Historien-Fenster, in dem das System im aktuellen Moment zwar existiert, aber in allen $K-1$ vorherigen Zeitschritten buchstäblich "nichts" war (Spur 0). Das ist unmöglich und stellt keine physikalisch erlaubte Konfiguration dar.
#
# **Die Analyse von Teil 2: Die physikalische Trajektorie**
#
# Ein echter, physikalischer Super-Vektor $X$ verhält sich völlig anders. Er hat in allen $K$ Blöcken vergleichbare Normen, da die Dichtematrizen benachbarter Zeitschritte fast gleich lang sind: $\Vert{}\rho_i\Vert{} \approx C$ für alle $i \in \{1, \dots, K\}$. Untersuchen wir nun, wie sich das Längenverhältnis (und damit Teil 2 unserer Wahrscheinlichkeit) verhält, wenn wir uns auf diese physikalischen Zustände beschränken.
#
# Dazu sehen wir zuerst, dass man mit allgemeinen $X = \big(\rho_1,\; \rho_2,\; \rho_3,\dots,\rho_{K}\big)^{\mathsf T}$ und $EX = \big(\overbrace{\sum_m T_m \rho_m}^{\rho_0},\; \rho_1,\; \rho_2,\dots,\rho_{K-1}\big)^{\mathsf T}$ sowie $\Vert{}X\Vert{}^2 = \sum_{i=1}^{K}\Vert{}\rho_i\Vert{}^2$ schreiben kann:
#
# $$
# \Vert{}EX\Vert{}^2 = \Big\Vert{}\sum_{m=1}^{K} T_m \rho_m\Big\Vert{}^2 + \sum_{i=1}^{K-1}\Vert{}\rho_i\Vert{}^2 \quad \implies \quad \Vert{}EX\Vert{}^2-\Vert{}X\Vert{}^2 = \Big\Vert{}\sum_{m=1}^{K}T_m\rho_m\Big\Vert{}^2-\Vert{}\rho_K\Vert{}^2 \quad \implies \quad \frac{\Vert{}EX\Vert{}^2}{\Vert{}X\Vert{}^2} = 1 + \frac{\Big\Vert{}\sum_{m=1}^{K} T_m \rho_m\Big\Vert{}^2 - \Vert{}\rho_K\Vert{}^2}{\Vert{}X\Vert{}^2}
# $$
#
# Wir setzen die Eigenschaften des physikalischen Zustands ein:
# 1. Die Gesamtlänge im Quadrat ist die Summe über alle $K$ Blöcke: $\Vert{}X\Vert{}^2 = \sum_{i=1}^{K}\Vert{}\rho_i\Vert{}^2 \approx K \cdot C^2$.
# 2. Der neue Block vorne hat nach der Propagation nahezu dieselbe Norm wie die anderen Blöcke: $\Vert\rho_0\Vert^2 = \left\Vert{}\sum_{m=1}^{K} T_m \rho_m\right\Vert{}^2 \approx C^2$.
# 3. Hinten wird die Norm der ältesten Zeitscheibe $\Vert{}\rho_K\Vert{}^2 \approx C^2$ abgezogen.
#
# In einem dissipativen System verliert das System über die Zeit winzig wenig an Reinheit (Dekohärenz), weshalb die Differenz zwischen dem neu entstehenden Block und dem herausfallenden Block eine extrem kleine negative Zahl $-\epsilon$ ergibt:
# $$ \Vert\rho_0\Vert^2 - \Vert{}\rho_K\Vert{}^2 = \Big\Vert{}\sum_{m=1}^{K} T_m \rho_m\Big\Vert{}^2 - \Vert{}\rho_K\Vert{}^2 = -\epsilon $$
#
# Setzen wir dies in unser relatives Längenverhältnis ein:
# $$ \frac{\Vert{}EX\Vert{}^2}{\Vert{}X\Vert{}^2} \approx 1 - \frac{\epsilon}{K \cdot C^2} \quad \implies \quad \frac{\Vert{}EX\Vert{}}{\Vert{}X\Vert{}} = \sqrt{1 - \frac{\epsilon}{K \cdot C^2}} \approx 1 - \frac{\epsilon}{2K \cdot C^2} \approx 0.9955 $$
#
# Da diese winzige Änderung $\epsilon$ durch die gewaltige Gesamtlänge des Registers ($K \cdot C^2$, da $K$ groß ist) geteilt wird, geht der Korrekturterm gegen null. Numerische Messungen entlang echter Trajektorien bestätigen diese physikalische Stabilität eindrucksvoll ($\frac{\Vert EX_n \Vert}{\Vert X_n \Vert} \approx 0.9955$). Wir sehen also: je größer $K$ desto besser.
#
# Für **Teil 2** unserer Wahrscheinlichkeit bedeutet das über $n=76$ Schritte:
# $$ \text{Teil 2} = \frac{\Vert E^n X_0 \Vert^2}{\Vert X_0 \Vert^2} \approx (0.9955)^{2 \cdot 76} \approx 0.505 $$
# Der reale physikalische Zerfall kostet uns also lediglich die Hälfte der Hardware-Shots und ist völlig harmlos.
#
# Zusammenfassend ergibt sich $p_{\rm total} = \text{Teil 1} \cdot \text{Teil 2} \approx (1.3 \times 10^{-23}) \cdot 0.505 \approx 6.7 \times 10^{-24}$. Obwohl die echte physikalische Dynamik (Teil 2) stabil ist, ruiniert uns Teil 1 die Simulation. Im großen Raum aller Zustände den wir bis jetzt betrachtet haben konnten wir zeigen dass leider $||E|| \ge \sqrt{2}$ und damit viel zu groß ist. Daher ist unser nächstes Ziel, uns auf einen kleineren Raum zu berschränken der nur alle physikalischen Zustände enthält. Das erreichen wir im folgenden mit der **Arnoldi-Kompression**.

# %% [markdown]
# ## Arnoldi compression
#
# Sei $\mathcal K_m(E,X_0) := \operatorname{span}\{X_0,EX_0,\dots,E^{m-1}X_0\}$ der Krylov-Raum, der nach Konstruktion die gesamte erreichbare physikalische Trajektorie enthält. Das Arnoldi-Verfahren baut mithilfe des Gram-Schmidt-Verfahren eine Orthonormalbasis für diesen Raum auf. das läuft wie folgt ab:
#
# - Wir nehmen den Startzustand $X_0$ und bringen ihn auf die Länge 1. Das ist unsere erste Achse: $\quad q_1 := \frac{X_0}{\Vert X_0 \Vert}$
# - Wir haben $q_1$ und wollen nun wissen, in welche "neue" Richtung uns der Propagator $E$ treibt.
#    1. Neuen Vektor erzeugen: Wir wenden $E$ auf den letzten erzeugten Basisvektoren (d.h. anfangs $q_1$) an: $\quad E q_i$.
#    2. Wir berechnen für $E q_i$ den überlap mit allen bereits existierenden Achsen: $\quad h_{ij} := \langle q_i, E q_j \rangle \text{  where  } i \leq j$
#    3. Wir ziehen alle diese Überlappe vom ursprünglichen Vektor $E q_i$ ab: $ \quad w_j := E q_j - \sum_{i=1}^{j} h_{ij} q_i$
#    4. Dieser Rest-Vektor $w_i$ zeigt nun in die neue Richtung, muss aber noch normiert werden: $\quad h_{j+1,j} := \Vert w_j \Vert \implies q_{j+1}:= \frac{w_j}{h_{j+1,j}}$
#    5. Neuen Vektor erzeugen: Wir berechnen $E q_{j+1}$ und das ganze beginnt von vorne
#
# > Proposition 15. Wenn $Q_m := (q_1\cdots q_m)$ die Basisvektoren als Spalten enthält und $H_m := (h_{ij})_{i,j\le m}$ eine obere Hessenberg-Matrix ist (alles unterhalb der ersten Nebendiagonale ist null), gilt:$$E\,Q_m = Q_mH_m + h_{m+1,m}\,q_{m+1}e_m^{\mathsf T},\qquad H_m = Q_m^\dagger E\,Q_m . \tag{6.3}$$
#
# - **Veranschaulichung mit einem Beispiel:** Machen wir das für $m = 3$. Unsere Matrizen sehen so aus:
#    - $Q_3$ ist eine Matrix, deren Spalten unsere drei generierten Basisvektoren sind: $Q_3 = \Big( q_1 \quad q_2 \quad q_3 \Big)$
#    - $H_3$ ist unsere $3 \times 3$ Hessenberg-Matrix. Sie enthält Nullen unter der ersten Nebendiagonale: $H_3 = \begin{pmatrix} h_{11} & h_{12} & h_{13} \\ h_{21} & h_{22} & h_{23} \\ 0 & h_{32} & h_{33} \end{pmatrix}$
#
#    Jetzt nutzen wir $w_j=h_{j+1,j}q_{j+1}$ um die Arnoldi-Regel $Eq_j = \sum_{i=1}^{j} h_{ij}q_i + h_{j+1,j} q_{j+1} = \sum_{i=1}^{j+1} h_{ij}q_i$, die man von oben ableiten kann, für jede Spalte einzusetzen:
#    - $Eq_1 = h_{11}q_1 + h_{21}q_2$
#    - $Eq_2 = h_{12}q_1 + h_{22}q_2 + h_{32}q_3$
#    - $Eq_3 = h_{13}q_1 + h_{23}q_2 + h_{33}q_3 + \mathbf{h_{43}q_4}$
#
#    Wir wenden die Matrix $E$ auf $Q_3$ an. Nach den Regeln der linearen Algebra bedeutet das einfach, dass $E$ auf jede Spalte von $Q_3$ einzeln angewendet wird
#    $$E \, Q_3 = E \, \Big( q_1 \quad q_2 \quad q_3 \Big) = \Big( Eq_1 \quad Eq_2 \quad Eq_3 \Big) = \Big( \underbrace{h_{11}q_1 + h_{21}q_2}_{\text{Spalte 1}} \quad\Big\vert{}\quad \underbrace{h_{12}q_1 + h_{22}q_2 + h_{32}q_3}_{\text{Spalte 2}} \quad\Big\vert{}\quad \underbrace{h_{13}q_1 + h_{23}q_2 + h_{33}q_3 + \mathbf{h_{43}q_4}}_{\text{Spalte 3}} \Big)$$
#    $\mathbf{h_{43}q_4}$ ist der Teil, der aus der Blase herausschwappt. Jetzt multiplizieren wir unsere beiden Matrizen $Q_3$ und $H_3$.
#    $$Q_3 \, H_3 = \Big( q_1 \quad q_2 \quad q_3 \Big) \begin{pmatrix} h_{11} & h_{12} & h_{13} \\ h_{21} & h_{22} & h_{23} \\ 0 & h_{32} & h_{33} \end{pmatrix} = \Big( \underbrace{h_{11}q_1 + h_{21}q_2}_{\text{Spalte 1}} \quad\Big\vert{}\quad \underbrace{h_{12}q_1 + h_{22}q_2 + h_{32}q_3}_{\text{Spalte 2}} \quad\Big\vert{}\quad \underbrace{h_{13}q_1 + h_{23}q_2 + h_{33}q_3}_{\text{Spalte 3}} \Big)$$
#
#    Vergleichen wir nun $E Q_3$ mit $Q_3 H_3$ sehen wir, dass die ersten beiden Spalten gleich sind aber in der 3. Spalte fehlt bei $Q_3 H_3$ der Term $\mathbf{h_{43}q_4}$. Wenn wir also die Differenz bilden erhalten wir mit Hilfe eines dyadischen Produktes:
#    $$E Q_3 - Q_3 H_3= \Big( \mathbf{0} \quad\Big\vert{}\quad \mathbf{0} \quad\Big\vert{}\quad \mathbf{h_{43}q_4} \Big) = \Big( h_{43}q_4 \cdot 0 \quad\Big\vert{}\quad h_{43}q_4 \cdot 0 \quad\Big\vert{}\quad h_{43}q_4 \cdot 1 \Big) = (h_{43}q_4) \cdot \begin{pmatrix} 0 & 0 & 1 \end{pmatrix} =  h_{43}q_4 e_3^{\mathsf T}$$
#
#    Wenn wir nun unsere Gleichung zusammenbauen, also $Q_3 H_3$ nehmen und diese exakte Differenz addieren, erhalten wir:$$E \, Q_3 = Q_3 H_3 + h_{43}q_4 e_3^{\mathsf T} \implies E \, Q_m = Q_m H_m + h_{m+1,m} q_{m+1} e_m^{\mathsf T}  \;\quad \blacksquare$$
#
#    Da alle Basisvektoren in $Q_m$ orthogonal zu einander sind, gilt $Q_m^\dagger Q_m = \mathbb 1_m$ und $Q_m^\dagger q_{m+1} = 0$ und wir können noch zeigen dass gilt: $$Q_m^\dagger E\,Q_m = Q_m^\dagger (Q_mH_m) + Q_m^\dagger (h_{m+1,m}\,q_{m+1}e_m^{\mathsf T}) = H_m + 0 = H_m \;\quad \blacksquare$$
#
#
#
# > **Proposition 16.** $\|H_m\|_2\le\|E\|_2$.
#
# Beweis. Für ein beliebiges $y \in \mathbb C^m$ gilt: $\Vert{}H_my\Vert{} = \Vert{}Q_m^\dagger EQ_my\Vert{} \le \Vert{}EQ_my\Vert{} \le \Vert{}E\Vert{}_2\Vert{}Q_my\Vert{} = \Vert{}E\Vert{}_2\Vert{}y\Vert{}$. Denn:
# - Die erste Ungleichung: $\Vert Q_m y \Vert^2 = (Q_m y)^\dagger (Q_m y) = y^\dagger \underbrace{(Q_m^\dagger Q_m)}_{=\,\mathbb{1}_m} y = y^\dagger y = \Vert y \Vert^2 \implies \Vert Q_m y \Vert = \Vert y \Vert$
# - Die zweite Ungleichung:
#    - $Q_m^\dagger$ ist eine $m \times N$-Matrix, die von links auf einen Vektor $x \in \mathbb{C}^N$ wirkt. Sie berechnet die Skalarprodukte von $x$ mit den $m$ Basisvektoren: $Q_m^\dagger x = \begin{pmatrix} \langle q_1, x \rangle \\ \vdots \\ \langle q_m, x \rangle \end{pmatrix}$
#    - Jeder Vektor $x$ lässt sich zerlegen in einen Anteil $x_\parallel$ im aufgespannten Krylov-Raum und einen orthogonalen Rest $x_\perp$: $x = x_\parallel + x_\perp \implies \Vert x \Vert^2 = \Vert x_\parallel \Vert^2 + \Vert x_\perp \Vert^2$
#    - Weil $Q_m^\dagger$ alle orthogonalen Anteile $x_\perp$ auf null abbildet ($Q_m^\dagger x_\perp = 0$), gilt: $\Vert Q_m^\dagger x \Vert^2 = \sum_{j=1}^m \vert{}\langle q_j, x \rangle\vert{}^2 = \Vert x_\parallel \Vert^2 \le \Vert x_\parallel \Vert^2 + \Vert x_\perp \Vert^2 = \Vert x \Vert^2 \implies \Vert Q_m^\dagger x \Vert \le \Vert x \Vert$
#
# Wie oben gezeigt, scheitert die Simulation am unitären Quantengatter, das uns für die Originalmatrix den globalen Worst-Case $s = \Vert E \Vert_2 \approx 1.41$ aufzwingt. Die **Arnoldi-Kompression** löst dieses Problem, indem sie die komprimierte Matrix $H_m$ nur aus jenen Richtungen aufbaut, die das System entlang der echten Trajektorie tatsächlich besucht ($X_0, EX_0, \dots$). Da die Dynamik niemals den unphysikalischen "Leeres-Universum"-Zustand annimmt, wird dieser normaufblähende Worst-Case gar nicht erst in die neue Basis aufgenommen.
#
# Dadurch stürzt die Operatornorm – und damit unser Skalierungsfaktor für das Quantengatter – auf ein physikalisch realistisches Niveau ab. Numerisch messen wir für $m=32$:
# $$ s = \Vert H_{32} \Vert_2 = 1.0028 $$
#
# Anstatt unseren Zustand pro Schritt durch $1.41$ zu teilen, stauchen wir ihn nun fast gar nicht mehr. Kombinieren wir nun Teil 1 mit dem stabilen physikalischen Zerfall (Teil 2 $\approx 0.505$), erhalten wir endlich eine berechenbare Erfolgsquote die viel größer als die $10^{-24}$ von zuvor ist:
#
# $$ p_{\rm total} = \underbrace{ \frac{1}{(1.0028)^{2\cdot 76}} }_{\text{Teil 1}} \cdot \underbrace{\frac{\Vert E^{76} X_0 \Vert^2}{\Vert X_0 \Vert^2}}_{\text{Teil 2}} \approx 0.65 \cdot 0.505 \approx 33\% $$
#
# Gleichzeitig schrumpft das benötigte Register massiv: Von den ursprünglichen $KD = 25 \times 4^2 = 400$ Dimensionen ($10$ Qubits) auf $m = 32$ Dimensionen ($6$ Qubits inklusive der Ancilla). Das liegt daran, dass wir nicht mehr die große $400 \times 400$ Matrix $E$ in ein Quantengatter übersetzen müssen, sondern direkt die kleine $32 \times 32$ Hessenberg-Matrix $H_{32}$ auf das Gatter-Grid geben. Für $32$ Dimensionen genügen $\lceil\log_2(32)\rceil = 5$ System-Qubits, womit inklusive des einen Post-Selection-Ancilla-Qubits lediglich $6$ Qubits angesteuert werden müssen.
#
#
# Die Wahl der Dimension $m$ ist ein echter Trade-off (ein Kompromiss) und kein reiner Konvergenzparameter:
#
# * **Ein zu kleines $m$** schneidet die physikalische Trajektorie zu früh ab. Der Fehler-Restterm $h_{m+1,m}$ aus Proposition 17 wird zu groß, wodurch die Dynamik ungenau wird und Information verloren geht.
# * **Ein zu großes $m$** zwingt das Arnoldi-Verfahren, weit über die physikalisch besuchte Trajektorie hinaus in den Gesamtraum vorzudringen. Dabei werden genau jene unphysikalischen Richtungen in die Basis $Q_m$ aufgenommen, die Proposition 14 als "normaufblähend" identifiziert hat. Dadurch steigt die Operatornorm $\Vert{}H_m\Vert{}_2$ wieder in Richtung $\sqrt{2}$ an, und der Bestrafungsfaktor $s^{2n}$ lässt die Erfolgswahrscheinlichkeit in (5.3) erneut zusammenbrechen.
#
# Für HEOM ist dieser optimale Bereich sehr breit ($m = 32$: Fehler nur $1.5\times 10^{-3}$, bei $p=0.33$). Für das Pfadintegral hingegen – dessen Operator $E$ aus MPS-abgeschnittenen Abbildungen zusammengebaut wird und das deutlich ausgeprägter nicht-normal ist – führt ein $m = 64$ bereits dazu, dass die Norm auf $\Vert{}H_m\Vert{}_2 = 1.243$ ansteigt und die Wahrscheinlichkeit sofort auf $p = 2.5\times 10^{-18}$ abstürzt.
#
# > Proposition 17. Wenn $h_{m+1,m} = 0$, dann ist der Raum $\mathcal K_m$ invariant unter $E$ und es gilt:
# > $$E^{\,n}X_0 = \Vert{}X_0\Vert{}\,Q_mH_m^{\,n}e_1\qquad\text{für alle }n\ge 0. \tag{6.4}$$
#
# Beweis. Wenn $h_{m+1,m} = 0$ ist, reduziert sich (6.3) auf $EQ_m = Q_mH_m$. Wendet man $E$ nochmal an, erhält man $E^2Q_m = E (Q_mH_m) = (EQ_m)H_m = (Q_mH_m)H_m = Q_mH_m^2$, und per Induktion folgt $E^nQ_m = Q_mH_m^n$. Da $q_1 := \frac{X_0}{\Vert X_0 \Vert}$ und $Q_m = \begin{pmatrix} q_1 & q_2 & \dots & q_m \end{pmatrix}$, folgt $$X_0 = \Vert{}X_0\Vert{}\,q_1 = ||X_0|| \cdot \begin{pmatrix} q_1 & q_2 & \dots & q_m \end{pmatrix} \cdot e_1 = \Vert{}X_0\Vert{}\,Q_m e_1$$
# Die Anwendung von $E^n$ auf deis Gleichung ergibt wegen $E^n Q_m = Q_m H_m^n$ genau Gleichung (6.4). $\;\blacksquare$
#
# Der Term $h_{m+1,m}$ beschreibt einen Beitrag zur Dynamik der außerhalb des Raumes liegt der von der Basis $Q_m$ aufgespannt wird. D.h. dieser Teil der Dynamik wird von der Arnoldi Compression vernachlässigt. Das sehen wir da nach der exakten Proposition 15 $E\,Q_m = Q_mH_m + h_{m+1,m}\,q_{m+1}e_m^{\mathsf T}$ gilr, wir aber für die fortlaufende Dynamik nur $E^{\,n}X_0 = \Vert{}X_0\Vert{}\,Q_mH_m^{\,n}e_1$ verwenden und spmit den Term $h_{m+1,m}$ vernachlässigen. Daher muss $m$ ausreichend groß gewählt werden, damit $h_{m+1,m}$ ausreichend klein ist. Dieses Abschneiden der Dynamik ist der Einzige Fehler in der Arnoldi Compression.
#
# Man kann auch zeigen dass ein großes $K$ die Norm $\Vert H_m \Vert_2$ kleiner werden lässt. Dazu erinnern wir uns an folgenden Ausdruck von oben: $$\frac{\Vert Ex \Vert}{\Vert x \Vert} = \sqrt{1 - \frac{\epsilon}{K \cdot C^2}} = 1 - \frac{\epsilon}{2K \cdot C^2} + \mathcal{O}\left(\frac{1}{K^2}\right) = 1 + \mathcal{O}\left(\frac{1}{K}\right) \tag{1}$$.
#
# Nach Definition ist die $L^2$-Operatornorm von $\Vert H_m \Vert_2 = \sup_{\substack{y \in \mathbb{C}^m \\ \Vert y \Vert = 1}} \Vert H_m y \Vert$. Da $Q_m$ eine Isometrie ist ($Q_m^\dagger Q_m = \mathbb{1}_m$), gilt für jeden Einheitsvektor $y \in \mathbb{C}^m$ mit $x := Q_m y \in \mathcal{K}_m$: $\Vert x \Vert^2 = y^\dagger Q_m^\dagger Q_m y = y^\dagger y = \Vert y \Vert^2 = 1$. Die exakte Arnoldi-Gleichung lautet $E Q_m = Q_m H_m + h_{m+1,m} q_{m+1} e_m^{\mathsf T}$. Multiplikation von rechts mit $y$ ergibt:$$Ex = E Q_m y = \underbrace{Q_m H_m y}_{\in \mathcal{K}_m} + \underbrace{h_{m+1,m} (e_m^{\mathsf T} y) q_{m+1}}_{\perp \mathcal{K}_m}$$Wegen der paarweisen Orthogonalität von $Q_m$ und $q_{m+1}$ gilt nach dem Satz des Pythagoras: $\Vert Ex \Vert^2 = \Vert Q_m H_m y \Vert^2 + \vert{}h_{m+1,m}\vert{}^2 \vert{}y_m\vert{}^2 = \Vert H_m y \Vert^2 + \vert{}h_{m+1,m}\vert{}^2 \vert{}y_m\vert{}^2$. Umstellen nach $\Vert H_m y \Vert$ liefert:$$\Vert H_m y \Vert = \sqrt{\Vert Ex \Vert^2 - \vert{}h_{m+1,m}\vert{}^2 \vert{}y_m\vert{}^2} \le \Vert Ex \Vert \tag{2}$$Für einen hinreichend großen Krylov-Rang $m$ fällt der Truncation-Fehler $h_{m+1,m} \approx 0$ extrem klein aus, womit Gleichung (2) zur asymptotischen Gleichheit wird: $\Vert H_m y \Vert \approx \Vert Ex \Vert$.
# Setzen wir (3) und die Identität $\Vert x \Vert = 1$ in die Definition der Operatornorm ein, lässt sich das Supremum über alle normierten Vektoren $x \in \mathcal{K}_m$ ausdrücken:$$\begin{aligned} \Vert H_m \Vert_2 &= \sup_{\substack{y \in \mathbb{C}^m \\ \Vert y \Vert = 1}} \Vert H_m y \Vert \approx \sup_{\substack{x \in \mathcal{K}_m \\ \Vert x \Vert = 1}} \Vert Ex \Vert = \sup_{\substack{x \in \mathcal{K}_m \\ x \neq \mathbf{0}}} \frac{\Vert Ex \Vert}{\Vert x \Vert} \end{aligned}$$Da der Krylov-Raum $\mathcal{K}_m = \operatorname{span}\{X_0, EX_0, \dots, E^{m-1}X_0\}$ ausschließlich aus Linearkombinationen balancierter Trajektorien-Zustände besteht, gilt für alle $x \in \mathcal{K}_m$ die Schranke (1):
# $$s \equiv \Vert H_m \Vert_2 \approx \sup_{\substack{x \in \mathcal{K}_m \\ x \neq \mathbf{0}}} \left( 1 - \frac{\epsilon}{2K \cdot C^2} \right) = 1 + \mathcal{O}\left(\frac{1}{K}\right)$$
# Grenzwertbildung für ein unendlich langes Gedächtnisfenster liefert unmittelbar: $\lim_{K \to \infty} \Vert H_m \Vert_2 = \lim_{K \to \infty} s = 1 \qquad \blacksquare$
#
#
#
# ## Die vollständige Simulations-Pipeline (Master-Gleichung)
#
# Betrachten wir die rechte Seite von Gleichung (6.4) genau:$$E^{\,n}X_0 = \underbrace{\Vert X_0 \Vert \, Q_m}_{\text{Klassische Rück-Übersetzung}} \cdot \underbrace{H_m^{\,n} e_1}_{\text{Quanten-Dynamik}}$$
# Diese Struktur teilt den Algorithmus in drei völlig getrennte Phasen auf:
# - Phase 1: Klassische Vorbereitung (Pre-Processing)Der klassische Computer berechnet die Arnoldi-Kompression für ein kleines $m$ (z. B. $m=32$). Er liefert uns:
#    1. Die winzige Matrix $H_m \in \mathbb{C}^{m \times m}$.
#    2. Die Basis $Q_m \in \mathbb{C}^{N \times m}$ (die wir klassisch speichern).
#    3. Den extrem gutmütigen Skalierungsfaktor $s = \Vert H_m \Vert_2 \approx 1.0028$.
# - Phase 2: Die Dynamik auf dem Quantencomputer. Der Quantencomputer muss niemals die große Matrix $E$ sehen und er muss auch nicht den komplizierten Startvektor $X_0$ laden. Er ist ausschließlich für die Dynamik $H_m^{\,n} e_1$ im $m$-dimensionalen Raum zuständig.
#    1. Der Startzustand: Der $m$-dimensionale Vektor $e_1 = (1, 0, \dots, 0)^{\mathsf T}$.
#    2. Der Schaltkreis (Sz.-Nagy): Wir bauen das unitäre Dilatations-Gatter $U_{H}$ jetzt ausschließlich für die kleine Matrix $H_m$: $U_{H} = \begin{pmatrix} H_m/s & B \\ C & D \end{pmatrix}$
#    3. Die Ausführung: Wir wenden dieses Gatter $n$-mal auf unseren Null-Zustand an: $(U_{H})^n \vert{}00\dots0\rangle$.Nach $n$ Schritten messen wir die Qubits und erhalten (bis auf den Faktor $s^n$) den komprimierten Vektor $y_n \in \mathbb{C}^m$: $$\begin{aligned} y_n &= H_m y_{n-1} = s \cdot \langle 0 \vert_E U_H \big( \vert{}0\rangle_E \otimes y_{n-1} \big) = s \cdot \langle 0 \vert_E U_H \bigg( \vert{}0\rangle_E \otimes \Big[ s \cdot \langle 0 \vert_E U_H \big( \vert{}0\rangle_E \otimes y_{n-2} \big) \Big] \bigg) \\ &= s \cdot \langle 0 \vert_E U_H \Bigg( \vert{}0\rangle_E \otimes \bigg[ s \cdot \langle 0 \vert_E U_H \Big( \vert{}0\rangle_E \otimes \big[ s \cdot \langle 0 \vert_E U_H ( \vert{}0\rangle_E \otimes y_{n-3} ) \big] \Big) \bigg] \Bigg) \\ &\;\;\dots = s^n \cdot \underbrace{\langle 0 \vert_E U_H \Bigg( \vert{}0\rangle_E \otimes \dots \Big[ \langle 0 \vert_E U_H \big( \vert{}0\rangle_E \otimes e_1 \big) \Big] \dots \Bigg) }_{n\text{-fache Schachtelung}} = H_m^n e_1 \end{aligned}$$
#    D.h. wir machen die selbe evolution wie zuvor nur mit einer kleineren Matrix auf einem kleinerem Raum der nur aus den relevanten Zuständen aufgespannt wird. Wir müssen $m$ groß genug wählen damit der kleine Raum groß genug bleibt und sich der Fehöer in grenzen hält.
# - Phase 3: Klassische Rekonstruktion (Post-Processing)Wir haben nun vom Quantencomputer einen winzigen $m$-dimensionalen Vektor $y_n$ ausgeben lassen. Dieser Vektor enthält die komplette komprimierte Historie des Systems zum Zeitschritt $n$.Um daraus den echten, großen physikalischen Super-Vektor $X_n$ (mit allen $K$ Dichtematrizen) zu machen, nutzen wir wieder Gleichung (6.4):$$X_n \approx \Vert X_0 \Vert \, Q_m \cdot y_n$$Der klassische Computer nimmt die Matrix $Q_m$ aus Phase 1 und projiziert das Ergebnis des Quantencomputers ($y_n$) einfach wieder in den vollen $N$-dimensionalen Raum zurück. Anschließend skaliert er ihn mit der Startlänge $\Vert X_0 \Vert$.
# Die rechte Seite der Formel stimmt nun exakt. Aber auf der linken Seite steht noch der Super-Vektor $X_n$.
# $X_n$ ist ein gigantischer Vektor, der die gesamten Dichtematrizen der letzten $K$ Zeitschritte enthält. Wenn die Simulation nach $n$ Schritten fertig ist, interessiert uns dieses alte Gedächtnis aber nicht mehr.Wir wollen *nur* den allerneuesten Zustand zum Zeitpunkt $n$ haben. Dafür nutzen wir den Projektor $\Pi = \begin{pmatrix} \mathbb{1}_D & \mathbf{0} & \cdots & \mathbf{0} \end{pmatrix} \in \mathbb{R}^{D \times KD}$, der den obersten Block der Länge $D = d^2$ herausschneidet und die restlichen $K-1$ Vergangenheits-Blöcke verwirft:
# $$ \operatorname{vec}\rho_n = \Pi \, X_n = \Pi \cdot ||X_0|| \cdot Q_m \cdot s^n \cdot \underbrace{ \langle 0 \vert_E U \Bigg( \vert{}0\rangle_E \otimes \dots \Big[ \langle 0 \vert_E U \big( \vert{}0\rangle_E \otimes \mathbf{y_0} \big) \Big] \dots \Bigg) }_{\text{Das macht die reine Quantenhardware mit } m \text{ Qubits}} $$
#
#
# ### 2. Der Ablauf innerhalb eines Zeitschritts $t$
#
# Um den Zustand $t$ Zeitschritte in die Zukunft zu entwickeln, wird für jeden Schritt $t$ ein eigener Circuit gebaut und $t$-mal iteriert:
#
# * **Initialisierung:**
#   Das System-Register wird in den Start-Krylov-Zustand $|y_0\rangle = |0\dots0\rangle$ versetzt, das Ancilla-Qubit auf $|0\rangle_{\text{anc}}$.
#
# * **Schritt 1 (Erste Multiplikation):**
#   * Das Gatter $U$ wird angewendet: $\to \left(\frac{H_m}{s} |y_0\rangle\right) \otimes |0\rangle + |\dots\rangle \otimes |1\rangle$ und das Ancilla-Qubit wird auf das klassische Bit `c_anc[0]` gemessen.
#   * **Messung ergibt `0`:** Der Zustand des Systems kollabiert exakt auf den gewünschten unnormierten Vektor $|y_1\rangle \propto H_m |y_0\rangle \implies$ Erfolg
#   * **Messung ergibt `1`:** Der Versuch ist fehlgeschlagen (Kollaps in den Fehlerzweig) und wird abgebrochen.
#
# * **Reset & Vorbereitung:**
#   * Das Ancilla-Qubit wird per `qc.reset(q_anc[0])` aktiv wieder in den reinen $|0\rangle$-Zustand zurückgesetzt, während das System-Register seinen kollabierten Zustand $|y_1\rangle$ behält.
#
# * **Schritt 2 bis $t$ (Wiederholte Multiplikation):**
#   * Ergab die Ancillamessung oben 0, wird dasselbe Gatter $U$ erneut auf das modifizierte System und das zurückgesetzte Ancilla angewendet:
#     $$U \big(|y_1\rangle \otimes |0\rangle_{\text{anc}}\big) = \left(\frac{H_m^2}{s^2} |y_0\rangle\right) \otimes |0\rangle + |\dots\rangle \otimes |1\rangle$$
#   * Das Ancilla wird auf `c_anc[1]` gemessen und wieder auf $|0\rangle$ gesetzt.
#   * Dieser Zyklus wiederholt sich insgesamt $t$-mal.
